# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('/Users/stanislavprihoda/Documents/Code/Courses/Python_and_ML_courses/Timeseries_Python/_sources/TSA_COURSE_NOTEBOOKS/03-Pandas-Visualization/df1.csv',index_col=0)

# %%
df2 = pd.read_csv('/Users/stanislavprihoda/Documents/Code/Courses/Python_and_ML_courses/Timeseries_Python/_sources/TSA_COURSE_NOTEBOOKS/03-Pandas-Visualization/df2.csv')

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1['A'].plot.hist()

# %%
df1['A'].plot.hist(edgecolor='k').autoscale(enable=True,axis='both',tight=True)

# %%
df1['A'].plot.hist(bins=80,edgecolor='k')

# %%
df1['A'].plot.hist(grid=True)

# %%
df2.head()
# Out:
#           a         b         c         d  e
# 0  0.039762  0.218517  0.103423  0.957904  x
# 1  0.937288  0.041567  0.899125  0.977680  y
# 2  0.780504  0.008948  0.557808  0.797510  x
# 3  0.672717  0.247870  0.264071  0.444358  z
# 4  0.053829  0.520124  0.552264  0.190008  y

# %%
df2.plot.bar()

# %%
df2.plot.bar(stacked=True)

# %%
df2.plot.barh(stacked=True)

# %%
df2.plot.line(y=['a','b','c','d'],figsize=(10,4),lw=4)

# %%
df2.plot.area()

# %%
df2.plot.area(alpha=0.3)

# %%
df2.plot.area(stacked=False,alpha=0.3)

# %%
df1.plot.scatter(x='A',y='B')

# %%
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm')

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*50,alpha=0.3,c='D',cmap='coolwarm')

# %%
df2.plot.box()

# %%
df2.plot.kde()

# %%
import numpy as np

# %%
df = pd.DataFrame(np.random.randn(1000,2),columns=['a','b'])

# %%
df.plot.hexbin(x='a',y='b',gridsize=25)

# %% [markdown]
# ### customizing plots

# %%
df2['c'].plot.line(figsize=(10,3),ls='-.',c='red')

# %%
title = "My plot title"
xlabel = 'My X data'
ylabel = 'My Y data'

# %%
ax = df2['c'].plot.line(title=title)
ax.set(xlabel=xlabel,ylabel=ylabel)
# Out:
# [Text(0, 0.5, 'My Y data'), Text(0.5, 0, 'My X data')]

# %%
ax = df2['c'].plot.line(title=title)
ax.set(xlabel=xlabel,ylabel=ylabel)

# %%
ax = df2.plot.line()
ax.legend(loc=2,bbox_to_anchor=(1.0,1.0))

# %% [markdown]
# ## excercise

# %%
df3 = pd.read_csv('/Users/stanislavprihoda/Documents/Code/Courses/Python_and_ML_courses/Timeseries_Python/_sources/TSA_COURSE_NOTEBOOKS/03-Pandas-Visualization/df3.csv',index_col=0)

# %%
df3.head()
# Out:
#              produced  defective
# weekday
# 1.Monday           73          7
# 2.Tuesday          75         10
# 3.Wednesday        86          7
# 4.Thursday         64          7
# 5.Friday           70          6

# %%
len(df3)
# Out:
# 500

# %%
df3.plot.scatter(x='produced',y='defective',figsize=(10,3),c='Red',s=5)

# %%
df3['produced'].plot.hist()

# %%
df3['produced'].plot.hist(edgecolor='k').autoscale(enable=True,axis='x',tight=True)

# %%
df3.boxplot(by='weekday',column=['produced']);

# %%
df3['defective'].plot.kde()

# %%
df3['defective'].plot.kde(lw=4,ls='--')

# %%
df3.iloc[:30].plot.area(stacked=False,alpha=0.3);

# %%
ax=df3.iloc[:30].plot.area(stacked=False,alpha=0.3)
ax.legend(loc=7,bbox_to_anchor=(1.275,0.5));
